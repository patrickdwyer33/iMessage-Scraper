# %%
import pandas as pd
import sqlite3
import os
import datetime
import time

# %%
cur_dir = os.getcwd()
parent_dir = os.path.split(cur_dir)[0]
src_data_path = os.path.join(parent_dir, 'Library', 'Messages', 'chat.db')
src_data_path
# Out:
# '/Users/patrickdwyer/Library/Messages/chat.db'

# %%
# substitute username with your username
conn = sqlite3.connect(src_data_path)
# connect to the database
cur = conn.cursor()
# get the names of the tables in the database
cur.execute(" select name from sqlite_master where type = 'table' ")
names = []
for name in cur.fetchall():
    print(name)
    names.append(name)
# Out:
# ('_SqliteDatabaseProperties',)
# ('deleted_messages',)
# ('sqlite_sequence',)
# ('chat_handle_join',)
# ('sync_deleted_messages',)
# ('message_processing_task',)
# ('handle',)
# ('sync_deleted_chats',)
# ('message_attachment_join',)
# ('sync_deleted_attachments',)
# ('kvtable',)
# ('chat_message_join',)
# ('message',)
# ('chat',)
# ('attachment',)
# ('sqlite_stat1',)

# %%
# get the entries of the message table using pandas
messages = pd.read_sql_query("select * from message", conn)
messages.head()
messages.columns
# Out:
# Index(['ROWID', 'guid', 'text', 'replace', 'service_center', 'handle_id',
#        'subject', 'country', 'attributedBody', 'version', 'type', 'service',
#        'account', 'account_guid', 'error', 'date', 'date_read',
#        'date_delivered', 'is_delivered', 'is_finished', 'is_emote',
#        'is_from_me', 'is_empty', 'is_delayed', 'is_auto_reply', 'is_prepared',
#        'is_read', 'is_system_message', 'is_sent', 'has_dd_results',
#        'is_service_message', 'is_forward', 'was_downgraded', 'is_archive',
#        'cache_has_attachments', 'cache_roomnames', 'was_data_detected',
#        'was_deduplicated', 'is_audio_message', 'is_played', 'date_played',
#        'item_type', 'other_handle', 'group_title', 'group_action_type',
#        'share_status', 'share_direction', 'is_expirable', 'expire_state',
#        'message_action_type', 'message_source', 'associated_message_guid',
#        'associated_message_type', 'balloon_bundle_id', 'payload_data',
#        'expressive_send_style_id', 'associated_message_range_location',
#        'associated_message_range_length', 'time_expressive_send_played',
#        'message_summary_info', 'ck_sync_state', 'ck_record_id',
#        'ck_record_change_tag', 'destination_caller_id', 'sr_ck_sync_state',
#        'sr_ck_record_id', 'sr_ck_record_change_tag', 'is_corrupt',
#        'reply_to_guid', 'sort_id', 'is_spam', 'has_unseen_mention',
#        'thread_originator_guid', 'thread_originator_part'],
#       dtype='object')

# %%
# get the handles to apple-id mapping table
handles = pd.read_sql_query("select * from handle", conn)
handles.head()
# Out:
#    ROWID            id country   service uncanonicalized_id person_centric_id
# 0      1  +19175651968      us  iMessage         9175651968              None
# 1      2  +13124054400      us  iMessage         3124054400              None
# 2      3  +19255886132      US  iMessage               None              None
# 3      4  +12487610953      us  iMessage         2487610953              None
# 4      5  +16504250933      US  iMessage               None              None

# %%
# and join to the messages, on handle_id
messages.rename(columns={'ROWID' : 'message_id'}, inplace = True)
handles.rename(columns={'id' : 'phone_number', 'ROWID': 'handle_id'}, inplace = True)
temp = pd.merge(messages[['text', 'handle_id', 'date','is_sent', 'message_id', 'type', 'account_guid', 'guid', 'associated_message_type', 'associated_message_guid', 'message_action_type', 'message_source']],  handles[['handle_id', 'phone_number']], on ='handle_id', how='left')
temp.message_source.describe()
# Out:
# count    387952.0
# mean          0.0
# std           0.0
# min           0.0
# 25%           0.0
# 50%           0.0
# 75%           0.0
# max           0.0
# Name: message_source, dtype: float64

# %%
messages.columns
# Out:
# Index(['message_id', 'guid', 'text', 'replace', 'service_center', 'handle_id',
#        'subject', 'country', 'attributedBody', 'version', 'type', 'service',
#        'account', 'account_guid', 'error', 'date', 'date_read',
#        'date_delivered', 'is_delivered', 'is_finished', 'is_emote',
#        'is_from_me', 'is_empty', 'is_delayed', 'is_auto_reply', 'is_prepared',
#        'is_read', 'is_system_message', 'is_sent', 'has_dd_results',
#        'is_service_message', 'is_forward', 'was_downgraded', 'is_archive',
#        'cache_has_attachments', 'cache_roomnames', 'was_data_detected',
#        'was_deduplicated', 'is_audio_message', 'is_played', 'date_played',
#        'item_type', 'other_handle', 'group_title', 'group_action_type',
#        'share_status', 'share_direction', 'is_expirable', 'expire_state',
#        'message_action_type', 'message_source', 'associated_message_guid',
#        'associated_message_type', 'balloon_bundle_id', 'payload_data',
#        'expressive_send_style_id', 'associated_message_range_location',
#        'associated_message_range_length', 'time_expressive_send_played',
#        'message_summary_info', 'ck_sync_state', 'ck_record_id',
#        'ck_record_change_tag', 'destination_caller_id', 'sr_ck_sync_state',
#        'sr_ck_record_id', 'sr_ck_record_change_tag', 'is_corrupt',
#        'reply_to_guid', 'sort_id', 'is_spam', 'has_unseen_mention',
#        'thread_originator_guid', 'thread_originator_part'],
#       dtype='object')

# %%
# get the chat to message mapping
chat_message_joins = pd.read_sql_query("select * from chat_message_join", conn)
# and join back to the temp table
chat_message_joins
# Out:
#         chat_id  message_id        message_date
# 0           984           1  654521310367000064
# 1           984           2  654507291638843008
# 2           984           3  654507269185949312
# 3           984           4  654503092986610432
# 4           984           5  654502886531523968
# ...         ...         ...                 ...
# 381539      976      388495  682899212743016960
# 381540      976      388496  682899229793999872
# 381541      976      388497  682899285638714496
# 381542      976      388499  682899391126107904
# 381543      976      388500  682899608336337536
#
# [381544 rows x 3 columns]

# %%
message_data = pd.merge(temp, chat_message_joins[['chat_id', 'message_id']], on = 'message_id', how='left')

# %%
message_attachment_joins = pd.read_sql_query("select * from message_attachment_join", conn)
message_attachment_joins.columns
# Out:
# Index(['message_id', 'attachment_id'], dtype='object')

# %%
attachments = pd.read_sql_query("select * from attachment", conn)
attachments
# Out:
#        ROWID                                       guid  created_date  \
# 0          1  at_0_DB1A8701-6A17-43CD-9EEC-CC9DFEDD5412     623541696
# 1          2  at_3_4C85FF55-8E3C-43F2-AA70-519F07B59468     623529614
# 2          3  at_2_4C85FF55-8E3C-43F2-AA70-519F07B59468     623529614
# 3          4  at_0_4015AFD0-428D-4C62-B7EF-67B94C6DEBD1     622420102
# 4          5  at_0_5C3A33B0-BB7E-4856-8510-7DA01813F9F4     622359371
# ...      ...                                        ...           ...
# 18957  18975       E5DEBE78-07D0-48DC-ADEC-469FA9651747     682887391
# 18958  18976       5DFF3117-D58A-456D-B674-21594F9EF630     682894443
# 18959  18977       F040439A-F03E-45DE-9D25-56A54ACF185D     682895968
# 18960  18978       09CABF61-0B99-496D-8597-6F5856E7C194     682896881
# 18961  18979       A9849584-64FF-4C1F-8500-97281C9B23A2     682899212
#
#        start_date                                           filename  \
# 0               0                                               None
# 1               0                                               None
# 2               0                                               None
# 3               0                                               None
# 4               0                                               None
# ...           ...                                                ...
# 18957           0  ~/Library/Messages/Attachments/1d/13/E5DEBE78-...
# 18958   682894443  ~/Library/Messages/Attachments/99/09/5DFF3117-...
# 18959   682895968  ~/Library/Messages/Attachments/98/08/F040439A-...
# 18960   682896882  ~/Library/Messages/Attachments/dd/13/09CABF61-...
# 18961   682899214  ~/Library/Messages/Attachments/8a/10/A9849584-...
#
#                                                  uti     mime_type  \
# 0                                         public.mp3    audio/mpeg
# 1      dyn.age81a5dzq7y066dbtf0g82peqf4hk2pdrb00n5xy          None
# 2      dyn.age81a5dzq7y066dbtf0g82peqf4hk2pdrb00n5xy          None
# 3                                      dyn.age80c65e          None
# 4                                  public.aifc-audio  audio/x-aiff
# ...                                              ...           ...
# 18957  dyn.age81a5dzq7y066dbtf0g82peqf4hk2pdrb00n5xy          None
# 18958                                    public.jpeg    image/jpeg
# 18959                                    public.jpeg    image/jpeg
# 18960                                    public.heic    image/heic
# 18961                                    public.jpeg    image/jpeg
#
#        transfer_state  is_outgoing  \
# 0                   0            0
# 1                   0            1
# 2                   0            1
# 3                   0            0
# 4                   0            0
# ...               ...          ...
# 18957               5            1
# 18958               5            0
# 18959               5            0
# 18960               5            0
# 18961               5            0
#
#                                                user_info  ...  \
# 0      b"bplist00\xd3\x01\x02\x03\x04\x05\x06TnameXut...  ...
# 1                                                   None  ...
# 2                                                   None  ...
# 3      b"bplist00\xd2\x01\x02\x03\x04TnameXuti-type_\...  ...
# 4      b"bplist00\xd3\x01\x02\x03\x04\x05\x06TnameXut...  ...
# ...                                                  ...  ...
# 18957                                               None  ...
# 18958  b'bplist00\xd8\x01\x02\x03\x04\x05\x06\x07\x08...  ...
# 18959  b'bplist00\xd8\x01\x02\x03\x04\x05\x06\x07\x08...  ...
# 18960  b'bplist00\xdd\x01\x02\x03\x04\x05\x06\x07\x08...  ...
# 18961  b'bplist00\xd8\x01\x02\x03\x04\x05\x06\x07\x08...  ...
#
#       sticker_user_info                                   attribution_info  \
# 0                  None                                               None
# 1                  None                                               None
# 2                  None                                               None
# 3                  None                                               None
# 4                  None                                               None
# ...                 ...                                                ...
# 18957              None                                               None
# 18958              None  b'bplist00\xd3\x01\x02\x03\x04\x0e\rWpgenszcVp...
# 18959              None  b'bplist00\xd3\x01\x02\x03\x04\x0e\rWpgenszcVp...
# 18960              None  b'bplist00\xd3\x01\x02\x03\x04\x0e\rWpgenszcVp...
# 18961              None  b'bplist00\xd3\x01\x02\x03\x04\x0e\rWpgenszcVp...
#
#        hide_attachment ck_sync_state  \
# 0                    0             3
# 1                    1             3
# 2                    1             3
# 3                    0             3
# 4                    0             3
# ...                ...           ...
# 18957                1             0
# 18958                0             0
# 18959                0             0
# 18960                0             0
# 18961                0             0
#
#                              ck_server_change_token_blob  \
# 0      b'bplist00\xd4\x01\x02\x03\x04\x05\x06\x07VX$v...
# 1      b'bplist00\xd4\x01\x02\x03\x04\x05\x06\x07VX$v...
# 2      b'bplist00\xd4\x01\x02\x03\x04\x05\x06\x07VX$v...
# 3      b'bplist00\xd4\x01\x02\x03\x04\x05\x06\x07VX$v...
# 4      b'bplist00\xd4\x01\x02\x03\x04\x05\x06\x07VX$v...
# ...                                                  ...
# 18957                                               None
# 18958                                               None
# 18959                                               None
# 18960                                               None
# 18961                                               None
#
#                                             ck_record_id  \
# 0      be149898d481fbc9ad3eabdbcdf7d7e13b16bfb4c48270...
# 1      c7b4fc8a02e91929d6dcc7d37d5b63f7fc38bdc5be87f2...
# 2      81a8a27a91ec34e6742577a39b00bb142b77a395ab31a2...
# 3      4604973d313e5271243029c15609e29b4660c0d6fa598e...
# 4      60a87be4e95ff266750bc9634d681d1aa5f20b86dff9fb...
# ...                                                  ...
# 18957                                               None
# 18958                                               None
# 18959                                               None
# 18960                                               None
# 18961                                               None
#
#                                    original_guid sr_ck_sync_state  \
# 0      at_0_DB1A8701-6A17-43CD-9EEC-CC9DFEDD5412                3
# 1      at_3_4C85FF55-8E3C-43F2-AA70-519F07B59468                3
# 2      at_2_4C85FF55-8E3C-43F2-AA70-519F07B59468                3
# 3      at_0_4015AFD0-428D-4C62-B7EF-67B94C6DEBD1                3
# 4      at_0_5C3A33B0-BB7E-4856-8510-7DA01813F9F4                3
# ...                                          ...              ...
# 18957       E5DEBE78-07D0-48DC-ADEC-469FA9651747                0
# 18958       5DFF3117-D58A-456D-B674-21594F9EF630                0
# 18959       F040439A-F03E-45DE-9D25-56A54ACF185D                0
# 18960       09CABF61-0B99-496D-8597-6F5856E7C194                0
# 18961       A9849584-64FF-4C1F-8500-97281C9B23A2                0
#
#                           sr_ck_server_change_token_blob  \
# 0      b'bplist00\xd4\x01\x02\x03\x04\x05\x06\x07VX$v...
# 1      b'bplist00\xd4\x01\x02\x03\x04\x05\x06\x07VX$v...
# 2      b'bplist00\xd4\x01\x02\x03\x04\x05\x06\x07VX$v...
# 3      b'bplist00\xd4\x01\x02\x03\x04\x05\x06\x07VX$v...
# 4      b'bplist00\xd4\x01\x02\x03\x04\x05\x06\x07VX$v...
# ...                                                  ...
# 18957                                               None
# 18958                                               None
# 18959                                               None
# 18960                                               None
# 18961                                               None
#
#                                          sr_ck_record_id
# 0      be149898d481fbc9ad3eabdbcdf7d7e13b16bfb4c48270...
# 1      c7b4fc8a02e91929d6dcc7d37d5b63f7fc38bdc5be87f2...
# 2      81a8a27a91ec34e6742577a39b00bb142b77a395ab31a2...
# 3      4604973d313e5271243029c15609e29b4660c0d6fa598e...
# 4      60a87be4e95ff266750bc9634d681d1aa5f20b86dff9fb...
# ...                                                  ...
# 18957                                               None
# 18958                                               None
# 18959                                               None
# 18960                                               None
# 18961                                               None
#
# [18962 rows x 23 columns]

# %%
attachments.rename(columns={'ROWID' : 'attachment_id'}, inplace = True)
message_data.columns
# Out:
# Index(['text', 'handle_id', 'date', 'is_sent', 'message_id', 'type',
#        'account_guid', 'guid', 'associated_message_type',
#        'associated_message_guid', 'message_action_type', 'message_source',
#        'phone_number', 'chat_id'],
#       dtype='object')

# %%
attachment_data = pd.merge(attachments, message_attachment_joins, on = 'attachment_id', how='left')
attachment_data.columns
# Out:
# Index(['attachment_id', 'guid', 'created_date', 'start_date', 'filename',
#        'uti', 'mime_type', 'transfer_state', 'is_outgoing', 'user_info',
#        'transfer_name', 'total_bytes', 'is_sticker', 'sticker_user_info',
#        'attribution_info', 'hide_attachment', 'ck_sync_state',
#        'ck_server_change_token_blob', 'ck_record_id', 'original_guid',
#        'sr_ck_sync_state', 'sr_ck_server_change_token_blob', 'sr_ck_record_id',
#        'message_id'],
#       dtype='object')

# %%
cream_data = pd.merge(message_data, attachment_data, on = 'message_id', how='left')
cream_data = cream_data[cream_data.chat_id == 976.0]
cream_data.columns
cream_data = cream_data[['text', 'phone_number', 'is_sent', 'message_id', 'chat_id', 'filename', 'uti', 'is_sticker', 'account_guid', 'guid_x', 'guid_y', 'associated_message_type', 'associated_message_guid', 'mime_type', 'original_guid','attachment_id']]
cream_data
# Out:
#                                                      text  phone_number  \
# 9       Loved “Foxes live up to 6 years in the wild on...  +19148863062
# 10      Emphasized “Everyone needs to see fox’s video ...  +15164196484
# 11         Everyone needs to see fox’s video about formal  +19149602412
# 12                               I have a brother John b   +14132819306
# 13                   Get ur head out of the gutter John B  +19145747734
# ...                                                   ...           ...
# 393077                                                  ￼  +19179231765
# 393078                                     Loved an image           NaN
# 393079                                     Loved an image  +19176801827
# 393080                                Laughed at an image  +19739085595
# 393081                                     Loved an image  +19145747734
#
#         is_sent  message_id  chat_id  \
# 9             0          10    976.0
# 10            0          11    976.0
# 11            0          12    976.0
# 12            0          13    976.0
# 13            0          14    976.0
# ...         ...         ...      ...
# 393077        0      388495    976.0
# 393078        1      388496    976.0
# 393079        0      388497    976.0
# 393080        0      388499    976.0
# 393081        0      388500    976.0
#
#                                                  filename          uti  \
# 9                                                     NaN          NaN
# 10                                                    NaN          NaN
# 11                                                    NaN          NaN
# 12                                                    NaN          NaN
# 13                                                    NaN          NaN
# ...                                                   ...          ...
# 393077  ~/Library/Messages/Attachments/8a/10/A9849584-...  public.jpeg
# 393078                                                NaN          NaN
# 393079                                                NaN          NaN
# 393080                                                NaN          NaN
# 393081                                                NaN          NaN
#
#         is_sticker                          account_guid  \
# 9              NaN  A28C8070-099D-4B76-B07A-1D1E20E4557B
# 10             NaN  A28C8070-099D-4B76-B07A-1D1E20E4557B
# 11             NaN  A28C8070-099D-4B76-B07A-1D1E20E4557B
# 12             NaN  A28C8070-099D-4B76-B07A-1D1E20E4557B
# 13             NaN  A28C8070-099D-4B76-B07A-1D1E20E4557B
# ...            ...                                   ...
# 393077         0.0  A28C8070-099D-4B76-B07A-1D1E20E4557B
# 393078         NaN  A28C8070-099D-4B76-B07A-1D1E20E4557B
# 393079         NaN  A28C8070-099D-4B76-B07A-1D1E20E4557B
# 393080         NaN  A28C8070-099D-4B76-B07A-1D1E20E4557B
# 393081         NaN  A28C8070-099D-4B76-B07A-1D1E20E4557B
#
#                                       guid_x  \
# 9       A82B15E9-4338-445B-9D65-08D1A91A4F56
# 10      8D7CC1E1-F32F-4908-B6F0-F1FCB5578AD7
# 11      206435C8-8EFA-46FD-AAE5-154F8C0E16BF
# 12      A2B3828B-7347-4C3B-9CAA-365D7B067415
# 13      24ABB3BE-4219-4C19-BD1E-1203C4E75CA4
# ...                                      ...
# 393077  974BB7AA-33A6-4D7E-B199-913D51D45AA0
# 393078  5FACD33F-B007-45CE-8D65-523808FB7383
# 393079  551BC1A4-8447-49E5-887C-8138A99F4514
# 393080  19C66CEC-F166-479F-964C-E7F536744A24
# 393081  AEDC782B-AC35-4BD7-B00F-A7F26A18C1F5
#
#                                       guid_y  associated_message_type  \
# 9                                        NaN                     2000
# 10                                       NaN                     2004
# 11                                       NaN                        0
# 12                                       NaN                        0
# 13                                       NaN                        0
# ...                                      ...                      ...
# 393077  A9849584-64FF-4C1F-8500-97281C9B23A2                        0
# 393078                                   NaN                     2000
# 393079                                   NaN                     2000
# 393080                                   NaN                     2003
# 393081                                   NaN                     2000
#
#                          associated_message_guid   mime_type  \
# 9       p:0/CD8588D6-0143-421C-8C45-40C6F165C6EA         NaN
# 10      p:0/206435C8-8EFA-46FD-AAE5-154F8C0E16BF         NaN
# 11                                          None         NaN
# 12                                          None         NaN
# 13                                          None         NaN
# ...                                          ...         ...
# 393077                                      None  image/jpeg
# 393078  p:0/974BB7AA-33A6-4D7E-B199-913D51D45AA0         NaN
# 393079  p:1/974BB7AA-33A6-4D7E-B199-913D51D45AA0         NaN
# 393080  p:0/974BB7AA-33A6-4D7E-B199-913D51D45AA0         NaN
# 393081  p:0/974BB7AA-33A6-4D7E-B199-913D51D45AA0         NaN
#
#                                original_guid  attachment_id
# 9                                        NaN            NaN
# 10                                       NaN            NaN
# 11                                       NaN            NaN
# 12                                       NaN            NaN
# 13                                       NaN            NaN
# ...                                      ...            ...
# 393077  A9849584-64FF-4C1F-8500-97281C9B23A2        18979.0
# 393078                                   NaN            NaN
# 393079                                   NaN            NaN
# 393080                                   NaN            NaN
# 393081                                   NaN            NaN
#
# [104981 rows x 16 columns]

# %%
def phone_number_cleaner(row):
    sent = row.is_sent
    number = row.phone_number
    if str(sent) == '0':
        return number
    else:
        return '+13128410148'


reaction_list = {'Emphasized', 'Loved', 'Liked',
'Laughed at', 'Disliked', 'Questioned'}


def message_cleaner(row):
    msg = row['text']
    temp_msg = str(msg).split('“')[0].strip()
    for reaction in reaction_list:
        if reaction in temp_msg:
            return reaction
    return 'none'


cream_data.phone_number = cream_data.apply(lambda x: phone_number_cleaner(x), axis = 1)
cream_data['reaction_type'] = cream_data.apply(lambda x: message_cleaner(x), axis = 1)
cream_data
# Out:
#                                                      text  phone_number  \
# 9       Loved “Foxes live up to 6 years in the wild on...  +19148863062
# 10      Emphasized “Everyone needs to see fox’s video ...  +15164196484
# 11         Everyone needs to see fox’s video about formal  +19149602412
# 12                               I have a brother John b   +14132819306
# 13                   Get ur head out of the gutter John B  +19145747734
# ...                                                   ...           ...
# 393077                                                  ￼  +19179231765
# 393078                                     Loved an image  +13128410148
# 393079                                     Loved an image  +19176801827
# 393080                                Laughed at an image  +19739085595
# 393081                                     Loved an image  +19145747734
#
#         is_sent  message_id  chat_id  \
# 9             0          10    976.0
# 10            0          11    976.0
# 11            0          12    976.0
# 12            0          13    976.0
# 13            0          14    976.0
# ...         ...         ...      ...
# 393077        0      388495    976.0
# 393078        1      388496    976.0
# 393079        0      388497    976.0
# 393080        0      388499    976.0
# 393081        0      388500    976.0
#
#                                                  filename          uti  \
# 9                                                     NaN          NaN
# 10                                                    NaN          NaN
# 11                                                    NaN          NaN
# 12                                                    NaN          NaN
# 13                                                    NaN          NaN
# ...                                                   ...          ...
# 393077  ~/Library/Messages/Attachments/8a/10/A9849584-...  public.jpeg
# 393078                                                NaN          NaN
# 393079                                                NaN          NaN
# 393080                                                NaN          NaN
# 393081                                                NaN          NaN
#
#         is_sticker                          account_guid  \
# 9              NaN  A28C8070-099D-4B76-B07A-1D1E20E4557B
# 10             NaN  A28C8070-099D-4B76-B07A-1D1E20E4557B
# 11             NaN  A28C8070-099D-4B76-B07A-1D1E20E4557B
# 12             NaN  A28C8070-099D-4B76-B07A-1D1E20E4557B
# 13             NaN  A28C8070-099D-4B76-B07A-1D1E20E4557B
# ...            ...                                   ...
# 393077         0.0  A28C8070-099D-4B76-B07A-1D1E20E4557B
# 393078         NaN  A28C8070-099D-4B76-B07A-1D1E20E4557B
# 393079         NaN  A28C8070-099D-4B76-B07A-1D1E20E4557B
# 393080         NaN  A28C8070-099D-4B76-B07A-1D1E20E4557B
# 393081         NaN  A28C8070-099D-4B76-B07A-1D1E20E4557B
#
#                                       guid_x  \
# 9       A82B15E9-4338-445B-9D65-08D1A91A4F56
# 10      8D7CC1E1-F32F-4908-B6F0-F1FCB5578AD7
# 11      206435C8-8EFA-46FD-AAE5-154F8C0E16BF
# 12      A2B3828B-7347-4C3B-9CAA-365D7B067415
# 13      24ABB3BE-4219-4C19-BD1E-1203C4E75CA4
# ...                                      ...
# 393077  974BB7AA-33A6-4D7E-B199-913D51D45AA0
# 393078  5FACD33F-B007-45CE-8D65-523808FB7383
# 393079  551BC1A4-8447-49E5-887C-8138A99F4514
# 393080  19C66CEC-F166-479F-964C-E7F536744A24
# 393081  AEDC782B-AC35-4BD7-B00F-A7F26A18C1F5
#
#                                       guid_y  associated_message_type  \
# 9                                        NaN                     2000
# 10                                       NaN                     2004
# 11                                       NaN                        0
# 12                                       NaN                        0
# 13                                       NaN                        0
# ...                                      ...                      ...
# 393077  A9849584-64FF-4C1F-8500-97281C9B23A2                        0
# 393078                                   NaN                     2000
# 393079                                   NaN                     2000
# 393080                                   NaN                     2003
# 393081                                   NaN                     2000
#
#                          associated_message_guid   mime_type  \
# 9       p:0/CD8588D6-0143-421C-8C45-40C6F165C6EA         NaN
# 10      p:0/206435C8-8EFA-46FD-AAE5-154F8C0E16BF         NaN
# 11                                          None         NaN
# 12                                          None         NaN
# 13                                          None         NaN
# ...                                          ...         ...
# 393077                                      None  image/jpeg
# 393078  p:0/974BB7AA-33A6-4D7E-B199-913D51D45AA0         NaN
# 393079  p:1/974BB7AA-33A6-4D7E-B199-913D51D45AA0         NaN
# 393080  p:0/974BB7AA-33A6-4D7E-B199-913D51D45AA0         NaN
# 393081  p:0/974BB7AA-33A6-4D7E-B199-913D51D45AA0         NaN
#
#                                original_guid  attachment_id reaction_type
# 9                                        NaN            NaN         Loved
# 10                                       NaN            NaN    Emphasized
# 11                                       NaN            NaN          none
# 12                                       NaN            NaN          none
# 13                                       NaN            NaN          none
# ...                                      ...            ...           ...
# 393077  A9849584-64FF-4C1F-8500-97281C9B23A2        18979.0          none
# 393078                                   NaN            NaN         Loved
# 393079                                   NaN            NaN         Loved
# 393080                                   NaN            NaN    Laughed at
# 393081                                   NaN            NaN         Loved
#
# [104981 rows x 17 columns]

# %%
#maps phone numbers to people's names
phone_number_map = {'19148863062': 'Andrew',
'19149602412': 'Goldy', '19175651968': 'Callum', '18472249266': 'Casey',
'18479229091': 'Judd', '19145747734': 'Alec', '16147955289': 'Katz',
'18605082030': 'Josh', '19739085595': 'Fox', '19178551473': 'Beau',
'13128410148': 'Patrick', '13868642668': 'Brock', '12402722900': 'Chuck',
'19176801827': 'Boxer', '12037337385': 'Denardi', '19179231765': 'Kimmel',
'12022571999': 'Alvaro', '14132819306': 'Wilson', 'joshleshem@icloud.com': 'Josh', 
'aggig13@gmail.com': 'Alec', 'zacharyfox22@gmail.com': 'Fox'}

# %%
creamer_map = {}

for number in phone_number_map.keys():
    name = phone_number_map[number]
    messages_sent = cream_data[cream_data.phone_number == '+'+number]
    counts = []
    index_list = []
    for reaction in reaction_list:
        reaction_data = messages_sent[messages_sent.reaction_type == reaction]
        counts.append(len(reaction_data))
        index_list.append(reaction)
    index_list.append('No Reaction')
    index_list.append('Total')
    normal_data = messages_sent[messages_sent.reaction_type == 'none']
    counts.append(len(normal_data))
    count = len(messages_sent)
    counts.append(count)
    creamer_map[name] = pd.Series(counts, index_list)

# %%
#result_data = pd.DataFrame(data=creamer_map, index = ['Emphasized', 'Loved', 'Liked', 'Laughed at', 'Disliked', 'Questioned', 'No Reaction', 'Total'])
#result_data.to_csv(os.path.join(os.getcwd(), 'Princeton_Data.csv'), encoding='utf-8')
cream_data.phone_number.unique()
# Out:
# array(['+19148863062', '+15164196484', '+19149602412', '+14132819306',
#        '+19145747734', '+18479229091', '+12022571999', '+12037337385',
#        '+16147955289', '+19179231765', '+18472249266', '+19178551473',
#        '+18605082030', '+19739085595', '+13128410148', '+19176801827',
#        '+19175651968', '+13868642668', '+12402722900', nan,
#        '+19145005868', 'zacharyfox22@gmail.com', 'aggig13@gmail.com',
#        'joshleshem@icloud.com'], dtype=object)

# %%
love_laugh_data = cream_data[(cream_data.reaction_type == 'Loved') | (cream_data.reaction_type == 'Laughed at')]
#love_laugh_data.to_csv(os.path.join(os.getcwd(), 'test.csv'))

# %%
text_love_laugh_counts = {}
for idx, row in love_laugh_data.iterrows():
    msg_id = row['associated_message_guid']
    if not pd.isnull(msg_id):
        msg_id = msg_id.split(':')[-1]
        msg_id = msg_id.split('/')[-1]
        text_love_laugh_counts[msg_id] = text_love_laugh_counts.get(msg_id, 0) + 1
    
count_map = {}
filetext_map = {}
name_map = {}

index = []
for msg_id in text_love_laugh_counts.keys():
    temp_df = cream_data[cream_data.guid_x == msg_id]
    if temp_df.shape[0] == 1:
        count_map[msg_id] = text_love_laugh_counts[msg_id]
        index.append(msg_id)
        number = temp_df.iloc[0].phone_number
        number = number.split('+')[-1].strip()
        if number == 15164196484 or number == 19145005868:
            continue
        name = phone_number_map.get(number, 'unknown')
        name_map[msg_id] = name
        file = temp_df.iloc[0].filename
        text = temp_df.iloc[0].text
        if not pd.isnull(file):
            filetext_map[msg_id] = file
        else:
            filetext_map[msg_id] = text
    

data = {'id_to_count': pd.Series(count_map.values(), index=index), 
       'id_to_content': pd.Series(filetext_map.values(), index=index), 
       'id_to_name': pd.Series(name_map.values(), index=index)}




output_data = pd.DataFrame(data=data, index = text_love_laugh_counts.keys())
output_data.columns
# Out:
# Index(['id_to_count', 'id_to_content', 'id_to_name'], dtype='object')

# %%
#output_data.sort_values(by=['id_to_count'], inplace=True)
#output_data.to_csv(os.path.join(os.getcwd(), 'Top_Cream.csv'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/7y/x0fcskqn7clfyvfnb4t8bh1w0000gn/T/ipykernel_5512/4070652788.py in <module>
# ----> 1 output_data.sort_values(by=['id_to_count'], inplace=True, reverse=True)
#       2 output_data.to_csv(os.path.join(os.getcwd(), 'Top_Cream.csv'))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: sort_values() got an unexpected keyword argument 'reverse'

# %%
person_love_laugh_ratios = {}

for name in phone_number_map.values():
    temp_df = output_data[output_data.id_to_name == name]
    temp_df = temp_df.dropna()
    length = len(temp_df)
    love_laugh_sum = temp_df.id_to_count.sum()
    ratio = (love_laugh_sum / length)
    person_love_laugh_ratios[name] = ratio
    print(f"{name}: {ratio}")
    
data_2 = {'Average Loves + Laughs': pd.Series(person_love_laugh_ratios.values(), index=person_love_laugh_ratios.keys())}

output_data_2 = pd.DataFrame(data=data_2, index = person_love_laugh_ratios.keys())

output_data_2.sort_values(by=['Average Loves + Laughs'], inplace=True)

output_data_2.to_csv(os.path.join(os.getcwd(), 'Creamer_Stats.csv'))

#cur.close()
#conn.close()
# Out:
# Andrew: 2.2723880597014925
# Goldy: 2.100507614213198
# Callum: 2.3924180327868854
# Casey: 2.058309037900875
# Judd: 2.2779850746268657
# Alec: 2.0544127405441275
# Katz: 2.937074829931973
# Josh: 2.335885167464115
# Fox: 2.816901408450704
# Beau: 3.0281899109792283
# Patrick: 2.777992277992278
# Brock: 4.6479591836734695
# Chuck: 2.8372591006423984
# Boxer: 2.5745257452574526
# Denardi: 2.5280898876404496
# Kimmel: 2.9350525310410696
# Alvaro: 2.142857142857143
# Wilson: 2.1348897535667963
# Josh: 2.335885167464115
# Alec: 2.0544127405441275
# Fox: 2.816901408450704

# %%
cur.close()
conn.close()
